# %%
import pandas as pd
import numpy as np


btc = pd.read_excel(r'C:\Users\Renato\Desktop\desafio_quant\desafio_quant_2023\assets\1d\BTCUSDT.xlsx')

def EWMA(s:pd.Series,window:int)->pd.Series:
    """
    Implementação da média movel exponencial
    atributos:
    s: series de preços 
    window: tamanho da janela movel
    return: serie de precos aplicada a media exponencial
    """
    ewma = s.ewm(span=window, adjust=False).mean()
    ewma.iloc[:window] = np.nan
    return ewma


def MACD():
    """
    implementação do MACD
    """
    pass

def RSI():
    """
    Implementação do indice de força relativa
    """
    pass

def DDD():
    """
    Implementação do DD diario 
    """
    pass

def MDD():
    """
    implementação do Maximo DD
    """
    pass

def SharpeRatio():
    """
    Precisa ser calculado em uma janela movel,
    atributos  = serie de retornos
    std dos retornos
    risk free rate (n sei qual q é) T-bond no periodo ?
    """
    pass

def CreateRandomPrtf():
    """Deve criar um portfolio aleatório com N+1 ativos,
    contabilizando cash,a soma deve ser igual a 100%.
    o retorno deve ser um vetor [xi,xii,xn] com os pesos dos ativos
    """
    pass

def RewardFuncGreed():
    """Deve receber um portfolio e calcular o retorno financeiro
    para um periodo N+1
    """
    pass


def RewardFuncRisk():
    """Deve receber um portfolio e calcular o indice de sharpe 
    para uma janela movel N
    deve retornar o valor 
    """
    pass

# %%
EWMA(btc.Close,100).plot()
EWMA(btc.Close,10).plot()
# Out:
# <Axes: >
